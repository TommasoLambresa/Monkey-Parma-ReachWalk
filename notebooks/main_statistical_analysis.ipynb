# %% [markdown]
# #### Selectivity Analysis (Mixed ANOVA and Post-Hoc Comparison)

# %%
# %load_ext autoreload
# %autoreload 2
from src.config import INTERIM_DATA_DIR

from src.statistical_analysis import analyze_selectivity

# Iterate over all subjects in the interim directory
for subject_dir in INTERIM_DATA_DIR.iterdir():
    if not subject_dir.is_dir():
        continue
        
    subject = subject_dir.name
    
    # Iterate over all sessions for the current subject
    for session_dir in subject_dir.iterdir():
        if not session_dir.is_dir():
            continue
            
        session = session_dir.name
                    
        print(f"Extracting informative channels for -> Subject: {subject} | Session: {session} | ALL EVENTS")
        
        analyze_selectivity(subject=subject, session=session, label_filter="R")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Extracting informative channels for -> Subject: Router | Session: Router_20220211 | ALL EVENTS
# [INFO] Found 2 .npz files. Merging...
# [INFO] Trials: {np.str_('grasp_floor'): np.int64(8), np.str_('grasp_hook'): np.int64(5), np.str_('steps'): np.int64(68)}
#
# ============================================================
#   DELTA band (1.0-4.0 Hz)
# ============================================================
#   Interaction significant (FDR): 14
#   Categories:
#     - ambiguous: 6
#     - mixed_steps_floor_diff: 3
#     - mixed_steps_hook_diff: 2
#     - non_informative: 56
#     - pan_motor_anisotropic: 1
#     - pan_motor_isotropic: 58
#     - pure_floor: 2
#
# ============================================================
#   THETA band (4.0-7.0 Hz)
# ============================================================
#   Interaction significant (FDR): 25
#   Categories:
#     - ambiguous: 13
#     - mixed_hook_floor_diff: 2
#     - mixed_hook_floor_similar: 1
#     - mixed_steps_floor_diff: 1
#     - mixed_steps_hook_diff: 6
#     - mixed_steps_hook_similar: 1
#     - non_informative: 54
#     - pan_motor_anisotropic: 1
#     - pan_motor_isotropic: 49
#
# ============================================================
#   ALPHA band (7.0-13.0 Hz)
# ============================================================
#   Interaction significant (FDR): 8
#   Categories:
#     - ambiguous: 1
#     - mixed_hook_floor_diff: 2
#     - mixed_hook_floor_similar: 1
#     - mixed_steps_floor_diff: 1
#     - non_informative: 74
#     - pan_motor_isotropic: 46
#     - pure_floor: 1
#     - pure_hook: 2
#
# ============================================================
#   BETA band (13.0-35.0 Hz)
# ============================================================
#   Interaction significant (FDR): 26
#   Categories:
#     - ambiguous: 19
#     - mixed_hook_floor_similar: 1
#     - mixed_steps_floor_diff: 1
#     - mixed_steps_hook_diff: 3
#     - mixed_steps_hook_similar: 1
#     - non_informative: 42
#     - pan_motor_isotropic: 60
#     - pure_steps: 1
#
# ============================================================
#   GAMMA band (40.0-200.0 Hz)
# ============================================================
#   Interaction significant (FDR): 32
#   Categories:
#     - ambiguous: 17
#     - mixed_steps_floor_diff: 3
#     - mixed_steps_hook_diff: 7
#     - mixed_steps_hook_similar: 1
#     - non_informative: 49
#     - pan_motor_anisotropic: 3
#     - pan_motor_isotropic: 47
#     - pure_hook: 1
#
# [INFO] Selectivity results saved to:
# C:\Users\andre\OneDrive - Scuola Superiore Sant'Anna\File di Tommaso Lambresa - Monkeys Parma\processed\Router\Router_20220211\selectivity_results.csv
# Extracting informative channels for -> Subject: Wifi | Session: Wifi_20210618 | ALL EVENTS
# [INFO] Found 2 .npz files. Merging...
# [INFO] Trials: {np.str_('grasp_floor'): np.int64(12), np.str_('grasp_hook'): np.int64(4), np.str_('steps'): np.int64(20)}
#
# ============================================================
#   DELTA band (1.0-4.0 Hz)
# ============================================================
#   Interaction significant (FDR): 3
#   Categories:
#     - ambiguous: 2
#     - non_informative: 117
#     - pan_motor_isotropic: 8
#     - pure_floor: 1
#
# ============================================================
#   THETA band (4.0-7.0 Hz)
# ============================================================
#   Interaction significant (FDR): 5
#   Categories:
#     - ambiguous: 3
#     - mixed_hook_floor_diff: 1
#     - non_informative: 123
#     - pure_steps: 1
#
# ============================================================
#   ALPHA band (7.0-13.0 Hz)
# ============================================================
#   Interaction significant (FDR): 1
#   Categories:
#     - non_informative: 119
#     - pan_motor_isotropic: 8
#     - pure_floor: 1
#
# ============================================================
#   BETA band (13.0-35.0 Hz)
# ============================================================
#   Interaction significant (FDR): 4
#   Categories:
#     - mixed_steps_hook_diff: 1
#     - non_informative: 109
#     - pan_motor_isotropic: 15
#     - pure_hook: 3
#
# ============================================================
#   GAMMA band (40.0-200.0 Hz)
# ============================================================
#   Interaction significant (FDR): 21
#   Categories:
#     - ambiguous: 18
#     - mixed_hook_floor_similar: 1
#     - mixed_steps_floor_diff: 1
#     - non_informative: 88
#     - pan_motor_isotropic: 19
#     - pure_floor: 1
#
# [INFO] Selectivity results saved to:
# C:\Users\andre\OneDrive - Scuola Superiore Sant'Anna\File di Tommaso Lambresa - Monkeys Parma\processed\Wifi\Wifi_20210618\selectivity_results.csv
